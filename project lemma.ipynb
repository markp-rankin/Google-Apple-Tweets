# %%
# Just a mess of imports. Much more to come.

import numpy as np
import pandas as pd
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import string
from nltk import FreqDist, word_tokenize
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import nltk
from gensim.models import Word2Vec
from nltk.tokenize import RegexpTokenizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, plot_confusion_matrix, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import MultinomialNB

# %%
# Added the encoding because I was getting an error. Don't know about you.

data = pd.read_csv('data.csv', encoding = "ISO-8859-1")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9093 entries, 0 to 9092
# Data columns (total 3 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   tweet_text                                          9092 non-null   object
#  1   emotion_in_tweet_is_directed_at                     3291 non-null   object
#  2   is_there_an_emotion_directed_at_a_brand_or_product  9093 non-null   object
# dtypes: object(3)
# memory usage: 213.2+ KB

# %%
data['is_there_an_emotion_directed_at_a_brand_or_product'].value_counts()
# Out:
# No emotion toward brand or product    5389
# Positive emotion                      2978
# Negative emotion                       570
# I can't tell                           156
# Name: is_there_an_emotion_directed_at_a_brand_or_product, dtype: int64

# %%
data.head()
# Out:
#                                           tweet_text  \
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs twe...
# 1  @jessedee Know about @fludapp ? Awesome iPad/i...
# 2  @swonderlin Can not wait for #iPad 2 also. The...
# 3  @sxsw I hope this year's festival isn't as cra...
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa M...
#
#   emotion_in_tweet_is_directed_at  \
# 0                          iPhone
# 1              iPad or iPhone App
# 2                            iPad
# 3              iPad or iPhone App
# 4                          Google
#
#   is_there_an_emotion_directed_at_a_brand_or_product
# 0                                   Negative emotion
# 1                                   Positive emotion
# 2                                   Positive emotion
# 3                                   Negative emotion
# 4                                   Positive emotion

# %%
data.iloc[0,0]
# Out:
# '.@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.'

# %%
data[data.isna().any(axis=1)]
# Out:
#                                              tweet_text  \
# 5     @teachntech00 New iPad Apps For #SpeechTherapy...
# 6                                                   NaN
# 16    Holler Gram for iPad on the iTunes App Store -...
# 32    Attn: All  #SXSW frineds, @mention Register fo...
# 33        Anyone at  #sxsw want to sell their old iPad?
# ...                                                 ...
# 9087  @mention Yup, but I don't have a third app yet...
# 9089  Wave, buzz... RT @mention We interrupt your re...
# 9090  Google's Zeiger, a physician never reported po...
# 9091  Some Verizon iPhone customers complained their...
# 9092  Ï¡Ïàü_ÊÎÒ£Áââ_£â_ÛâRT @...
#
#      emotion_in_tweet_is_directed_at  \
# 5                                NaN
# 6                                NaN
# 16                               NaN
# 32                               NaN
# 33                               NaN
# ...                              ...
# 9087                             NaN
# 9089                             NaN
# 9090                             NaN
# 9091                             NaN
# 9092                             NaN
#
#      is_there_an_emotion_directed_at_a_brand_or_product
# 5                    No emotion toward brand or product
# 6                    No emotion toward brand or product
# 16                   No emotion toward brand or product
# 32                   No emotion toward brand or product
# 33                   No emotion toward brand or product
# ...                                                 ...
# 9087                 No emotion toward brand or product
# 9089                 No emotion toward brand or product
# 9090                 No emotion toward brand or product
# 9091                 No emotion toward brand or product
# 9092                 No emotion toward brand or product
#
# [5802 rows x 3 columns]

# %%
data['emotion_in_tweet_is_directed_at'].value_counts()
# Out:
# iPad                               946
# Apple                              661
# iPad or iPhone App                 470
# Google                             430
# iPhone                             297
# Other Google product or service    293
# Android App                         81
# Android                             78
# Other Apple product or service      35
# Name: emotion_in_tweet_is_directed_at, dtype: int64

# %%
# Simplify

company = {'iPad': 'Apple',
            'Apple': 'Apple',
            'iPad or iPhone App': 'Apple',
            'Google': 'Google',
            'iPhone': 'Apple',
            'Other Google product or service': 'Google',
            'Android App': 'Google',
            'Android': 'Google',
            'Other Apple product or service': 'Apple'}
data['emotion_in_tweet_is_directed_at'] = data['emotion_in_tweet_is_directed_at'].map(company)

# %%
data['is_there_an_emotion_directed_at_a_brand_or_product'].value_counts()
# Out:
# No emotion toward brand or product    5389
# Positive emotion                      2978
# Negative emotion                       570
# I can't tell                           156
# Name: is_there_an_emotion_directed_at_a_brand_or_product, dtype: int64

# %%
print(data['tweet_text'].isna().sum())

data = data[~data['tweet_text'].isna()]
# Out:
# 1

# %%
# Simplify column names

data.rename(columns={'tweet_text': 'text', 'emotion_in_tweet_is_directed_at': 'brand', 'is_there_an_emotion_directed_at_a_brand_or_product': 'feelings'}, inplace=True)

# %%
###################### Simplify for now to create base model. Afterwards, may revisit. #####################

data.drop(data[data['feelings'] == "I can't tell"].index, inplace = True)

# %%
# Encode labels

feels = {'Negative emotion': 0,
        'Positive emotion': 1,
        'No emotion toward brand or product': 2}

data['feelings'] = data['feelings'].map(feels)

# %%
len(data)
# Out:
# 8936

# %%
###################### Simplify for now to create base model. Afterwards, definitely revisit. #####################

data = data[data['feelings'] <= 1]

# %%
len(data)
# Out:
# 3548

# %%
X = data['text'].map(word_tokenize)
target = data['feelings']

# %%
tokenizer = RegexpTokenizer(r'\w+')
hashtag = RegexpTokenizer(r'\#\w+')

# %%
data
# Out:
#                                                    text   brand  feelings
# 0     .@wesley83 I have a 3G iPhone. After 3 hrs twe...   Apple         0
# 1     @jessedee Know about @fludapp ? Awesome iPad/i...   Apple         1
# 2     @swonderlin Can not wait for #iPad 2 also. The...   Apple         1
# 3     @sxsw I hope this year's festival isn't as cra...   Apple         0
# 4     @sxtxstate great stuff on Fri #SXSW: Marissa M...  Google         1
# ...                                                 ...     ...       ...
# 9077  @mention your PR guy just convinced me to swit...   Apple         1
# 9079  &quot;papyrus...sort of like the ipad&quot; - ...   Apple         1
# 9080  Diller says Google TV &quot;might be run over ...  Google         0
# 9085  I've always used Camera+ for my iPhone b/c it ...   Apple         1
# 9088                      Ipad everywhere. #SXSW {link}   Apple         1
#
# [3548 rows x 3 columns]

# %%
stops = stopwords.words('english')
stops += list(string.punctuation)
stops.extend(['sxsw', 'sxswi', 'quot', 'mention', 'link', 'rt', 'amp', 'http', 'sxswrt', 'google', 'googles', 'app', 'apps', 'android', 'austin', 'quotgoogle', 'new', 'today', 'one', 'apple', 'ipad', 'iphone', 'ipad2', 'apples', 'quotapple'])

# %%
data['tokens'] = data['text'].apply(tokenizer.tokenize)
data['hash'] = data['text'].apply(hashtag.tokenize)
data
# Out:
#                                                    text   brand  feelings  \
# 0     .@wesley83 I have a 3G iPhone. After 3 hrs twe...   Apple         0
# 1     @jessedee Know about @fludapp ? Awesome iPad/i...   Apple         1
# 2     @swonderlin Can not wait for #iPad 2 also. The...   Apple         1
# 3     @sxsw I hope this year's festival isn't as cra...   Apple         0
# 4     @sxtxstate great stuff on Fri #SXSW: Marissa M...  Google         1
# ...                                                 ...     ...       ...
# 9077  @mention your PR guy just convinced me to swit...   Apple         1
# 9079  &quot;papyrus...sort of like the ipad&quot; - ...   Apple         1
# 9080  Diller says Google TV &quot;might be run over ...  Google         0
# 9085  I've always used Camera+ for my iPhone b/c it ...   Apple         1
# 9088                      Ipad everywhere. #SXSW {link}   Apple         1
#
#                                                  tokens                   hash
# 0     [wesley83, I, have, a, 3G, iPhone, After, 3, h...  [#RISE_Austin, #SXSW]
# 1     [jessedee, Know, about, fludapp, Awesome, iPad...                [#SXSW]
# 2     [swonderlin, Can, not, wait, for, iPad, 2, als...         [#iPad, #SXSW]
# 3     [sxsw, I, hope, this, year, s, festival, isn, ...                [#sxsw]
# 4     [sxtxstate, great, stuff, on, Fri, SXSW, Maris...                [#SXSW]
# ...                                                 ...                    ...
# 9077  [mention, your, PR, guy, just, convinced, me, ...     [#sxsw, #princess]
# 9079  [quot, papyrus, sort, of, like, the, ipad, quo...                [#SXSW]
# 9080  [Diller, says, Google, TV, quot, might, be, ru...       [#sxsw, #diller]
# 9085  [I, ve, always, used, Camera, for, my, iPhone,...        [#SXSW, #SXSWi]
# 9088                     [Ipad, everywhere, SXSW, link]                [#SXSW]
#
# [3548 rows x 5 columns]

# %%
data['tokens'] = data['tokens'].apply(lambda x: [word.lower() for word in x if word not in stops])
data['tokens'] = data['tokens'].apply(lambda x: [word.lower() for word in x if word not in stops])

# %%
lemmatizer = WordNetLemmatizer()
w_tokenizer = nltk.tokenize.WhitespaceTokenizer()

def lemmatize_text(text):
    try:
        return [lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)]
    except:
        print(text)

data['tokens'] = data['tokens'].apply(lemmatize_text)
# Out:
# anks', 'letting', 'us', 'know', 'heard', '2', 'giveaway']
# ['thanks', 'store', 'retweet']
# ['thanks', 'checking']
# ['makes', 'want', '1', 'use', 'uppward', '2', 'tshirt', 'clever', 'design', '3', 'jerk']
# ['impressive', 'popup', 'store', 'must', 'purchased', '2', 'enjoy']
# ['deleting']
# ['watching', '3d', 'rendering', 'team', 'put', 'together', 'awe', 'inspiring', 'like', 'jetsons', 'marissagoogle']
# ['popupstore', 'like', 'crack', 'house', 'mac', 'addicts']
# ['best', 'thing', 'saw', 'tonight', 'security', 'guards', 'protecting', '2', 'awesome']
# ['classiest', 'facist', 'company', 'america', 'kara', 'swisher']
# ['constant', 'switches', 'making', 'making', 'feel', 'like', 'giant']
# ['geeks', 'need', 'somewhere', 'downtown', 'line', 'get', '2', 'dropping']
# ['yes', 'party', 'glowing', 'cups']
# ['saw', 'huge', '2', 'line', 'popup', 'store', 'people', 'really', 'really', 'want']
# ['saw', '2', 'close', 'first', 'time', 'shiny']
# ['line', '2', 'store', 'demo', 'units', '5pm', 'fb']
# ['phone', 'way', 'battery', 'wise', 'believe', 'week', 'week', 'comfortable', 'typing', 'sixth', 'st']
# ['either', 'go', 'wait', 'line', 'buy', 'tricked', 'mom', 'birthday', 'guess', 'ª']
# ['oh', 'another', 'way', 'talk', 'shit', 'net', 'launch', 'major', 'social', 'network', 'called', 'circles', 'possibly']
# ['flap', 'loose', 'peeked', 'looks', 'like', 'store', 'built', 'day']
# ['thing', 'good', 'flash', 'mobs', 'hive', 'think', 'wins']
# ['oh', 'smart']
# ['journalists', 'spent', 'money', 'passes', 'afford', 'tv']
# ['setting', 'temporary', 'store', 'bother', 'store', 'coming', 'us']
# ['mayer', 'think', 'simplicity', 'lot', 'developing', 'products', 'jr']
# ['truck', 'need']
# ['go', 'blackberry', 'available']
# ['time', 'next', 'week', 'party']
# ['food', 'thought', 'prefer', 'website', 'scheduler', 'changed', 'life', 'interesting', 'smart', 'phones', 'changed', 'communications']
# ['hipstamatic', 'giving', 'away', 'hipstapaks', 'channels', 'news', 'ios']
# ['noticed', 'dst', 'coming', 'weekend', 'many', 'users', 'hour', 'late', 'come', 'sunday', 'morning']
# ['nice', 'pop', 'shop', 'time', 'p', 'arrived']
# ['well', 'place', 'us', 'get', '2', 'apparently', 'austinwins']
# ['still', 'waiting', 'someone', 'stop', '2', 'game', 'prize', 'waiting']
# ['tweeting', '2', 'jealous', 'wssxsw']
# ['sitting', 'lobby', 'hotel', '2am', 'free', 'wifi', 'set', 'yeah']
# ['putting', 'store', 'downtown', '2', 'tablet', 'disrupt', 'wait']
# ['setting', 'temporary', 'store', 'attendees', 'get', 'fix']
# ['tweeting', 'riding', 'thru', '210']
# ['dear', 'please', 'tell', 'us', 'soon', 'circles', 'unveiled', 'thanks']
# ['well', 'opening', 'temporary', 'store', 'downtown', '2', 'launch']
# ['p', 'throw', 'b', 'tchin', 'party', 'shout', 'spazmatics']
# ['wow', 'developed', '15k', 'newsapps']
# ['like', 'download', 'freak', 'jet', 'hilarious', 'see', 'learning', 'stuff']
# ['grab', 'betainvites', 'camera', 'raises', '1', '1m', 'valley', 'players', 'bit', 'ly', 'ea1zgd', 'via']
# ['omg', 'ûï', 'rumor', 'opening', 'temporary', 'store', 'downtown', '2', 'launch']
# ['marissa', 'mayer', '40', 'maps', 'use', 'mobile']
# ['tells', 'making', 'accessible', 'people', 'site', 'ready', 'poursite']
# ['latitude', 'make', 'big', 'push', 'breakthrough', 'year']
# ['mobile', 'activations', '200', '9', 'months', 'taking', 'huge', 'market', 'share', 'sxswmobileapps', 'accesssxsw']
# ['congrats', 'another', 'winner', 'case', 'going', 'mission', 'trip', 'sister', 'haiti', 'cbatsxsw']
# ['congrats', 'executing', 'event', 'guide', 'loaded', 'sxsw11']
# ['congrats', 'winning', 'last', 'case', 'boyfriend', 'aw', 'cbatsxsw']
# ['san', 'jose', 'surrounded', 'peeps', 'every', 'tech', 'nerds', 'dream', 'time', 'turn', 'charm', 'find', 'bff']
# ['congrats', 'bernd', 'florian', 'launch', 'guguchu', 'ticket', 'terminal', 'ahead']
# ['start', 'compete', 'bigger', 'guys', 'like', 'checkins', 'pnid']
# ['love', 'get', 'store', 'popping', 'downtown', 'tomorrow', 'lack', 'patience', 'douchebaggery']
# ['thrilled', 'former', 'chief', 'talent', 'officer', 'gap', 'advisory', 'board', 'innotribe']
# ['temp', 'store', '6th', 'congress', 'attendees', 'excuse', 'walking', 'around', '2']
# ['congrats', 'kenny', 'enjoys', 'spanking', 'case', 'look', 'happy']
# ['congrats', 'kenny', 'enjoys', 'spanking', 'case', 'look', 'happy', 'cbatsxsw']
# ['guy', 'next', 'bathroom', 'props', 'urinal', 'keeps', 'using', 'going', 'people', 'serious']
# ['early', 'purchase', '2', 'awesome', 'sweepstakes', 'giveaway', 'game', 'details', 'coming', 'soon']
# ['yet', 'see', 'someone', 'pc', 'dell', 'otherwise', 'macbook', 'pro', 'ipads']
# ['sell', '2s', 'attendees', 'worked', 'sold']
# ['planning', 'wait', 'store', 'get', 'infektd', 'might', 'players', 'crowd']
# ['tattoo', 'chalked', 'pavement', 'mean', 'applefanatic']
# ['toolkit', 'laptop', 'charger', 'h2o', 'bike', 'shades', 'walking', 'ad', 'touch', 'rei', 'sxswtoolkit']
# ['totally', 'digging', 'foursquare', 'time', 'craps', 'rematch', 'big', 'omaha']
# ['totally', 'mean', 'number', 'companies', 'seemed', 'offering', 'thing', 'sad', 'beat', 'give', 'guys']
# ['hotpot', 'good', 'services', 'force', 'anyways']
# ['hotpot', 'let', 'people', 'rate', 'guess', 'logical', 'business', 'progression', 'marissagoogle']
# ['hotpot', 'rate', 'restaurants', 'get', 'personalized', 'recos', 'eat', 'um', 'think', 'foursquare', 'yelp', 'etc', 'covered', 'already']
# ['hotpot', 'yelp', 'killer', 'impressive', 'integration', 'personalized', 'recommendations', 'really', 'fast']
# ['sounds', 'intriguing', 'lots', 'chatter', 'around', 'social', 'network', 'circles', 'kek']
# ['introducing', 'check', 'status', 'rewards', 'mobile']
# ['industry', 'party', 'gsdm', 'grand', 'affair']
# ['thing', 'addition', 'place', 'print', 'cuts', 'b', 'newsapps', 'panel']
# ['sets', 'temporary', 'store', 'im', 'lil', 'jealous']
# ['perfect', 'attention', 'detail', 'recreated', 'code', 'pac', 'man', 'doodle', 'original', 'bugs', 'included', 'googledoodles']
# ['better', 'sweets', 'time']
# ['bettercloud', 'computing', 'insight', 'benefit', 'data', 'centers', 'economies', 'scale', 'continual', 'improvements', 'pgi']
# ['battery', 'going', 'quickly', 'guy', 'behind', 'let', 'borrow', 'portable', 'charger', 'want']
# ['stumbling', 'around', 'lost', 'stay', 'contact', 'group', 'application']
# ['82', 'future', 'tablet', 'buyers', 'say', 'choose', 'see', 'pop', 'store']
# ['watching', 'twit', 'live', 'want', 'go', 'next', 'year', 'also', 'want', 'content', 'wait', 'awhile', 'always', 'buy', 'technology', 'late', 'anyway']
# ['great', 'visualisation', 'ghost', 'movement', 'logic', 'pacman', 'doodles', 'session', 'details']
# ['wow', 'suck', 'rebecca', 'black', 'fab5']
# ['could', 'search', 'engines', 'instead', 'useful', 'information', 'savebrands']
# ['would', 'great', 'partner', 'us', 'says', 'looking', 'distribution', 'better', 'products']
# ['room', 'full', 'design', 'headaches', 'talk']
# ['launches', 'route', 'around', 'traffic', 'offers', '3', 'options', 'keep', 'traffic', 'saves', '2yrs', 'worth', 'time', 'every', 'day']
# ['found', 'bbq', 'sauce', 'tech', 'texas', 'really', 'come', 'together']
# ['lines', 'around', 'block', '2', 'lucky', 'recipient']
# ['route', 'around', 'traffic', 'maps', 'saves', 'users', '2', 'years', 'worth', 'time', 'everyday']
# ['route', 'around', 'traffic', 'maps', 'feature', 'saving', 'users', '2', 'years', 'time', 'every', 'day', 'holytrafficjams']
# ['ungrateful', 'bc', 'much', 'shit', 'play', 'turn', 'shit']
# ['kind', 'funny', 'sad', 'release', 'line', 'longer', 'party', 'lines', 'saw', 'last', 'night', 'sheeple']
# ['ad', 'preferences', 'view', 'edit', 'thinks', 'like', 'seenocreepy']
# ['picked', 'mophie', 'charge', 'case', 'tradeshow', 'doubt', 'use', 'time', 'great', 'long', 'days']
# ['picked', 'white', 'store']
# ['catching', 'hotel', 'room', 'day', '1', 'also', 'tweeting']
# ['bad', 'news', 'update', 'pop', 'store', 'ipads', 'sure', 'tomorrow']
# ['another', 'super', 'smart', 'move', 'temporary', 'store']
# ['take', 'really', 'want', 'checkins']
# ['nice', 'gesture', 'lonely', 'planet', 'makes', 'guide', 'free']
# ['pressure', 'ahem', 'excuse', 'buy', 'mounts', '2', 'must', 'gadget', 'via']
# ['journal', 'momento', 'sale', 'grab', '59p', '99å']
# ['packed', 'house', 'bing', 'q', 'search', 'rankings', 'oh', 'hope', 'catfight', 'qagb']
# ['patented', 'something', 'e', 'age', 'domain', 'rankings', 'algorithm', 'mean', 'use', 'qagb']
# ['40', 'use', 'maps', 'mobile', 'marissa', 'mayer']
# ['packed', 'house', 'go', 'lynn', 'designing', 'interfaces', 'navigation', 'schemas', 'uxdes']
# ['used', 'example', 'good', 'navigation', 'via', 'mentionn']
# ['someone', 'held', 'giant', 'like', 'love']
# ['customer', 'service', 'top', 'notch', 'even', 'got', 'guys', 'hanging', 'line', 'giving', 'inventory', 'updates', 'nice']
# ['stellar', 'customer', 'service', 'store', 'wish', 'every', 'purchase', 'smooth']
# ['yup', 'showusyouricrazy', 'pop', 'store', 'day', 'release', 'could', 'b', 'genius', 'move', 'mktg', 'history']
# ['heading', 'aclu', 'eff', 'party', 'yep', 'throwing', 'back', 'reliving', 'old', 'times', 'fun']
# ['geeking', 'waited', 'line', 'product', 'missing', 'important', 'rite', 'passage']
# ['route', 'around', 'traffic', 'saving', 'drivers', '2', 'years', 'time', 'per', 'day', 'finding', 'best', 'route']
# ['route', 'around', 'traffic', 'pretty', 'sweet', 'route', 'around', 'saving', 'users', '2', 'years', 'day', 'efficient', 'time', 'environment']
# ['auto', 'completes', 'kawasaki', 'name', 'first', 'four', 'letters']
# ['waiting', 'outside', 'store', 'woohoo']
# ['ben', 'benieuwd', 'interrupt', 'regularly', 'scheduled', 'geek', 'programming', 'big', 'news', 'circles']
# ['need', 'buy', 'sure', 'need', 'q', 'store']
# ['dev', 'panel', 'indicates', 'screen', 'reader', 'works', 'widgets', 'native', 'ui', 'web', 'views', 'browser']
# ['v1', '2', 'go', 'live', 'better', 'updates', 'schedule', 'sync', 'would', 'love', 'know', 'think']
# ['valuable', 'device', 'far', 'ipod', 'charger']
# ['users', 'drive', '12b', 'miles', 'year', 'maps', 'navigation', 'jr']
# ['upgrade', 'newest', 'ios', 'yet', 'tweetdeck', 'unstable', 'nten', '11ntc']
# ['fuck', 'love', 'left', 'youtube', 'party', 'maggie', 'maes', 'fun', 'times', 'got', 'youtube', 'tube', 'socks', 'lol']
# ['genius', 'move', 'open', 'temp', 'store', 'downtown', 'via']
# ['wait', '4', '5', 'weeks', '2', 'appleatxdt', 'pop', 'shipments', 'daily', 'via']
# ['2', 'giveaway', 'full', 'force', 'person', 'friends', 'city', 'end', 'wins', 'hint', 'strong', 'email', 'list', 'works', 'well']
# ['already', 'download', 'free', 'music', 'sampler', 'itunes', 'itunes', 'good']
# ['waited', 'line', 'product', 'missing', 'important', 'rite', 'passage']
# ['thank', 'heavens', 'nice', 'travelers', 'got', 'charger', 'another', 'delayed', 'passenger']
# ['bounced', 'catch', 'marissa', 'mayer', 'speak', 'always', 'admired', 'intelligent', 'classy', 'successful', 'girlcrush']
# ['heading', 'shortly', 'record', 'video', 'popup', 'store', 'southby', 'expecting', 'big', 'sales']
# ['totally', 'overshadowing', 'wins', '2', 'arrives', 'tomorrow', '5', 'p']
# ['porting', 'everything', 'head', 'sunday', 'syncing', '3k', 'songs', 'takes']
# ['giving', 'away', 'mappers', 'entry', 'amazingly', 'easy', 'details']
# ['giving', 'away', '2', 'kick', 'time', 'visit', 'fb', 'page', 'info']
# ['photo', 'saving', '2', 'style', 'hpsxsw', 'taken', 'instagram']
# ['got', 'craving', 'minds', 'created', 'foodspotting']
# ['rescuing', 'virtual', 'robots', 'daily', 'life', 'envisioning', 'day', 'last', 'tv', 'broadcast', 'morning']
# ['got', 'vmware', 'talent', 'community', 'rockin', 'signing', 'talented', 'professionals', 'tonight', 'find']
# ['protip', 'avoid', 'area', 'stores', 'friday']
# ['auntie', 'voxpop', 'popular', 'worth', 'watch', 'many', 'phones', 'view']
# ['loving', 'w', 'channel']
# ['need', 'loving', 'volunteers', '10', '45am', '3']
# ['love', 'alt', 'universe', 'everyone', 'uses', 'products', 'fastest', 'way', 'reach', 'someone']
# ['know', '1', 'user', 'uses', 'tv', 'room', 'nobody', 'raises', 'hand', 'packed', 'room', 'socialviewing', 'session']
# ['mxm', 'made', 'awesome']
# ['awesomeness', 'opening', 'temporary', 'store', 'downtown', '2', 'launch']
# ['festival', 'time', 'omg', 'scared', 'got', 'netbook', 'firm', 'droid']
# ['dear', 'goer', 'please', 'look', 'fucking', 'walking', 'halls', 'thanks', 'hipsters', 'hilarious']
# ['grateful', 'bicycle', 'back', 'twitter', 'cursing', 'losing', 'hour', 'zzzs', 'battery', 'life']
# ['dear', 'suck', 'year', 'sitby', 'us', 'great', 'include', 'film', 'sessions']
# ['wow', 'big', 'attending', 'bringing', 'along', 'temporary', 'store']
# ['free', 'music', 'sampler', 'itunes', 'includes', 'barton', 'hollow', 'opens', 'itunes']
# ['free', 'sampler', 'itunes', 'freemusic']
# ['saw', 'someone', 'filming', 'trade', 'show', 'floor', 'w', 'teeny', 'hand', 'held', 'steady', 'cam', 'jealous']
# ['free', 'streams', 'downloads', 'via', 'free', 'winamp', 'market', 'direct', 'download', 'market']
# ['love', 'mac', 'pc', 'ratio', 'like', '25', '1', 'person', 'ratio', 'like', 'three', 'quarters', 'seriously', 'ton', 'ipads']
# ['know', 'target', 'audience', 'pop', 'shop', 'sell', '2', 'launch', 'day']
# ['popup', 'store', 'sold', 'nothing', 'battery', 'extenders', 'would', 'make', 'much', 'money']
# ['ever', 'doubt', 'influence', 'innovation', 'community', 'look', 'ipads', 'iphone4', 'everywhere']
# ['wish', 'free', '2s']
# ['crowd', 'swarms', '2', 'launch', 'via', 'sadly']
# ['crowd', 'swarms', '2', 'launch', 'via', 'sadly', 'via']
# ['crowd', 'swarms', 'launch', 'via', 'sxsw2011']
# ['crowd', 'swarms', '2', 'launch']
# ['crowd', 'swarms', '2', 'launch', 'via']
# ['crowd', 'swarms', '2', 'launch', 'via']
# ['looking', 'fwd', 'dj', 'dark', 'party', 'tonight', 'great', 'first', 'day']
# ['right', 'track', 'clever', 'set', 'open', 'popup', 'shop', 'core', 'action']
# ['tight', 'w', 'lot', 'friends', 'work', 'employees', 'used', 'work', 'tight', 'w', 'tight', 'w', 'twitter']
# ['tweeted', 'fast', 'appears', 'may', 'preview', 'circles', 'social', 'endeavor']
# ['well', 'hope', 'make', 'easier', 'find', 'little', 'wants', 'say', 'hi']
# ['wish', 'wish', '2', 'said']
# ['ummmm', 'awesome', 'party', 'djroe', 'store', 'downtown', 'open', 'til', 'midnight']
# ['chances', 'booth', 'selling', '2s']
# ['think', 'presentation', 'nice', 'see', 'retail', 'peeps']
# ['going', 'share', 'photos', 'video', 'ireport', 'cnn']
# ['wait', 'time', 'lookin', 'like', 'store', 'north', 'already', 'sold', 'word', 'inventory']
# ['debating', 'laptop', 'take', 'rather', 'taking', '2', 'firstworldproblems']
# ['see', 'white', '2', 'know', 'apartment', 'looks', 'like', 'needs', 'wires']
# ['said', 'able', 'get', '2', 'opening', 'pop', 'store']
# ['livetapp', 'raffling', '2', 'check', 'tweet', 'show', 'entered', 'win', 'music', 'rewards']
# ['thirsty', 'gadget', 'using', 'charge', 'anywhere', 'happy', 'share', 'juice']
# ['jonathan', 'zaggle', 'showed', 'us', 'cool', 'free', 'texting', 'called', 'zms']
# ['walkin', 'street', 'navigating', 'via', 'tweeting', 'random', 'guy', 'yelping', 'welcome']
# ['umm', 'would', 'ûï', 'keep', 'winning', 'shit', 'thanks', 'killer', 'case', 'û']
# ['news', 'popular', 'kids', 'the_daily', 'terrible', 'concept', 'anyway']
# ['knows', 'game', 'bring', 'people']
# ['hmmm', 'taxi', 'magic', 'appear', 'magic']
# ['great', '3d', 'xml', 'visualization', 'skiers', 'using', 'location', 'data']
# ['festivalexplorer', 'finally', 'solves', 'music', 'musica', 'musiek', 'musique', 'musik', 'ù_¾', 'â', 'ù_¾', 'î', 'é']
# ['pop', 'store', 'smart', 'marketing']
# ['even', 'starts', 'captured', 'attention', 'whole', 'show', 'win', 'must', 'taking', 'lessons', 'sheen', 'fb']
# ['people', 'brilliant', 'spider', 'secret', 'bryce', 'manor', '99', 'cents', 'right', 'buy']
# ['pdx', 'tomorrow', 'drop', 'note', 'tmsxsw', 'pop', 'retail', 'store', 'epicenter', 'madness']
# ['love', 'opened', 'party', 'settle', 'argument', 'parentheses', 'use', 'wordnerd']
# ['group', 'texting', 'war', 'heats', 'fast', 'society', 'launches', 'updates', 'û_']
# ['far', 'mifi', 'rock', 'solid', 'cc']
# ['lovely', 'get', 'thanks', 'awesome', 'integration']
# ['started', 'planning', 'last', 'night', 'official', 'solid', 'resource', 'still', 'comes', 'short', 'scheduling']
# ['tapworthy', 'winning', 'tigerblood', 'tenets', 'design']
# ['day', '1', 'expected', 'everyone', 'glued', 'included']
# ['best', 'newly', 'added', 'goes', 'awesome', '2011', 'come', 'day', 'amazing', 'day']
# ['biomimicry', 'basis', 'design', 'problem', 'solving', 'studying', 'flocking', 'swarming', 'behavior', 'understand', 'collab', 'brilliant']
# ['guy', 'talk', 'explaining', 'made', 'realistic', 'twitter', 'bots', 'experiment', 'gee', 'thanks']
# ['leaving', 'bag', 'home', 'traveling', 'light', 'hand', 'really', 'need', 'lug', 'around', 'impedimenta']
# ['absolutely', 'beautiful', 'day', 'mall', 'guys', 'track', '2']
# ['way', 'means', 'get', '2']
# ['think', 'effing', 'hubby', 'line', '2', 'someone', 'point', 'towards', 'line', 'wife', 'number', '2']
# ['friend', 'photosharing', 'developed', 'ck', 'show', 'support']
# ['crazy', 'much', 'culture', 'documented', 'doodles']
# ['day', 'geekest', 'place', 'world', 'right', 'yes', 'u', 'queue', 'opens', 'hidden', 'store']
# ['looks', 'interesting', 'launch', 'major', 'social', 'network', 'called', 'circles', 'possibly']
# ['looks', 'interesting', 'good', 'luck', 'localmind', 'available']
# ['getting', 'store', 'w', '4', 'others']
# ['data', 'finally', 'sorted', 'next', 'stop']
# ['dropped', 'macbook', 'pro', 'walking', '2', 'sounding', 'pretty', 'appealing', 'right', 'somehow', 'adapt', 'overcome']
# ['creativity', 'prompt', 'use', 'maps', 'virtually', 'take', 'walk', 'used', 'take', 'kid', 'see', 'memories', 'come', 'courtesy']
# ['pretty', 'sure', 'panelist', 'thinks', 'drowning', 'success', 'fucking', 'insane']
# ['happy', 'discovr', 'named', 'top', 'ten', 'must', '2', 'fight', 'way', 'thru', 'queue']
# ['apparently', 'line', 'get', 'store', 'grew', '2', 'blocks', '5', 'blocks', 'past', '30', 'mins', 'wut']
# ['apparently', 'block', 'tweets']
# ['way', 'see', 'tonight', 'hopefully', 'san', 'francisco', 'international', 'airport', 'sfo']
# ['stopped', 'tron', 'legacy', 'lounge', 'audio', 'sync', 'function', 'extras', 'pretty', 'cool']
# ['second', 'day', 'using', 'really', 'impressed', 'magnetic', 'cover', 'pure', 'brilliance', 'using', 'laptop', 'old', 'school']
# ['way', 'love', 'discuss', 'breeds', 'midst', 'pre', 'madness']
# ['absolutely', 'timely', 'good', 'schtuff', 'people', 'finder', '4', 'japan', 'quake', 'iqlab']
# ['good', 'job', 'yes', 'gowalla', 'wins', 'best', 'andoid', 'team', 'choice', 'awards', 'thanks']
# ['top', 'story', 'schools', 'marketing', 'experts', 'thousands', 'town', 'demonstrate', 'social', 'mar']
# ['yep', 'believe', 'set', 'pop', 'store', 'oh', 'wait', 'yes']
# ['yes', 'picked', '2', '1st']
# ['yes', 'favorited', 'want', 'win', 'need', 'win', 'doo', 'dah', 'doo', 'dah', 'pushio']
# ['hey', 'anyone', 'signing', 'group', 'texting', 'groupme', 'got', 'else', 'kinda', 'useless']
# ['look', 'everyone', 'zomg', 'got', '2', 'first', 'day']
# ['favorite', 'thanks', 'coming', 'getting']
# ['bet', 'man', 'kindle', 'sure', 'pre', 'order', 'amazon']
# ['buy', 'used', 'pick', 'tomorrow']
# ['could', 'buy', '2', 'tmrw', 'pop', 'store']
# ['guys', 'ever', 'plan', 'attending', 'need', '4', 'things', 'skinny', 'jeans', 'flannel', 'shirt', 'beard', 'imanoutcast']
# ['might', 'also', 'appreciate', 'tweetcaster', 'zip', 'feature', 'let', 'hide', 'keywords', 'hashtag', 'incl', 'course']
# ['realize', 'still', 'padless', 'gave', 'away', 'case', 'bmm', 'need', 'win', 'next', 'first']
# ['get', '2', 'save', 'back', 'lugging', 'laptop', 'sxswmymistake']
# ['see', 'line', 'front', 'store', 'nothing', 'like', 'tech', 'geek', 'gathering', 'launch', 'day']
# ['know', 'made', 'see', 'bunch', 'grown', 'men', 'hooting', 'getting', '2']
# ['essentials', 'mine', 'pocket', 'camera', 'laptop', 'extra', 'cords']
# ['4', 'cases', 'rad', 'ready', 'stop', 'tomorrow', 'get', 'zazzlesxsw']
# ['pr', 'guy', 'convinced', 'switch', 'back', 'great', 'coverage', 'princess']
# ['papyrus', 'sort', 'like', 'nice', 'lol', 'lavelle']
# ['diller', 'says', 'tv', 'might', 'run', 'playstation', 'xbox', 'essentially', 'ready', 'diller']
# ['always', 'used', 'camera', 'b', 'c', 'image', 'stabilizer', 'mode', 'suggestions', 'cam', 'w', 'feature']
# ['everywhere']

# %%
data
# Out:
#                                                    text   brand  feelings  \
# 0     .@wesley83 I have a 3G iPhone. After 3 hrs twe...   Apple         0
# 1     @jessedee Know about @fludapp ? Awesome iPad/i...   Apple         1
# 2     @swonderlin Can not wait for #iPad 2 also. The...   Apple         1
# 3     @sxsw I hope this year's festival isn't as cra...   Apple         0
# 4     @sxtxstate great stuff on Fri #SXSW: Marissa M...  Google         1
# ...                                                 ...     ...       ...
# 9077  @mention your PR guy just convinced me to swit...   Apple         1
# 9079  &quot;papyrus...sort of like the ipad&quot; - ...   Apple         1
# 9080  Diller says Google TV &quot;might be run over ...  Google         0
# 9085  I've always used Camera+ for my iPhone b/c it ...   Apple         1
# 9088                      Ipad everywhere. #SXSW {link}   Apple         1
#
#      tokens                   hash
# 0      None  [#RISE_Austin, #SXSW]
# 1      None                [#SXSW]
# 2      None         [#iPad, #SXSW]
# 3      None                [#sxsw]
# 4      None                [#SXSW]
# ...     ...                    ...
# 9077   None     [#sxsw, #princess]
# 9079   None                [#SXSW]
# 9080   None       [#sxsw, #diller]
# 9085   None        [#SXSW, #SXSWi]
# 9088   None                [#SXSW]
#
# [3548 rows x 5 columns]

# %%
################ CHANGE BELOW TO TF IDF ####################

# %%
X_train, X_test, y_train, y_test = train_test_split(data['text'], data['feelings'])

count_vectorizer = CountVectorizer()

X_train_counts = count_vectorizer.fit_transform(X_train)
X_test_counts = count_vectorizer.transform(X_test)

# %%
# Straight up stolen code, tweak to needs later or discard because it's useless
# Haven't bothered changing labels because the graph isn't useful for our purposes

from sklearn.decomposition import PCA, TruncatedSVD
import matplotlib
import matplotlib.patches as mpatches


def plot_LSA(test_data, test_labels, savepath="PCA_demo.csv", plot=True):
        lsa = TruncatedSVD(n_components=2)
        lsa.fit(test_data)
        lsa_scores = lsa.transform(test_data)
        color_mapper = {label:idx for idx,label in enumerate(set(test_labels))}
        color_column = [color_mapper[label] for label in test_labels]
        colors = ['orange','blue','blue']
        if plot:
            plt.scatter(lsa_scores[:,0], lsa_scores[:,1], s=8, alpha=.8, c=test_labels, cmap=matplotlib.colors.ListedColormap(colors))
            red_patch = mpatches.Patch(color='orange', label='Irrelevant')
            green_patch = mpatches.Patch(color='blue', label='Disaster')
            plt.legend(handles=[red_patch, green_patch], prop={'size': 30})


fig = plt.figure(figsize=(16, 16))          
plot_LSA(X_train_counts, y_train)
plt.show()

# %%
clf = LogisticRegression(C=30.0, class_weight='balanced', solver='newton-cg', 
                         multi_class='multinomial', n_jobs=-1, random_state=40)
clf.fit(X_train_counts, y_train)

y_predicted_counts = clf.predict(X_test_counts)

# %%
def get_metrics(y_test, y_predicted):  
    # true positives / (true positives+false positives)
    precision = precision_score(y_test, y_predicted, pos_label=None,
                                    average='weighted')             
    # true positives / (true positives + false negatives)
    recall = recall_score(y_test, y_predicted, pos_label=None,
                              average='weighted')
    
    # harmonic mean of precision and recall
    f1 = f1_score(y_test, y_predicted, pos_label=None, average='weighted')
    
    # true positives + true negatives/ total
    accuracy = accuracy_score(y_test, y_predicted)
    return accuracy, precision, recall, f1

accuracy, precision, recall, f1 = get_metrics(y_test, y_predicted_counts)
print("accuracy = %.3f, precision = %.3f, recall = %.3f, f1 = %.3f" % (accuracy, precision, recall, f1))
# Out:
# accuracy = 0.876, precision = 0.881, recall = 0.876, f1 = 0.878

# %%
confusion_matrix(y_test, y_predicted_counts)
# Out:
# array([[ 83,  49],
#        [ 61, 694]], dtype=int64)

# %%
rf = RandomForestClassifier()
rf.fit(X_train_counts, y_train)

y_predicted_counts = rf.predict(X_test_counts)

accuracy, precision, recall, f1 = get_metrics(y_test, y_predicted_counts)
print("accuracy = %.3f, precision = %.3f, recall = %.3f, f1 = %.3f" % (accuracy, precision, recall, f1))
# Out:
# accuracy = 0.895, precision = 0.894, recall = 0.895, f1 = 0.875

# %%
confusion_matrix(y_test, y_predicted_counts)
# Out:
# array([[ 45,  87],
#        [  6, 749]], dtype=int64)

# %%
rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
param_grid = {
    'bootstrap': [True, False],
    'max_depth': [None, 100, 110, 120, 130],
    'max_features': ['auto'],
    'min_samples_leaf': [1, 2],
    'min_samples_split': [2, 3, 4],
    'n_estimators': [55, 60, 65]
}
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, scoring='f1', 
                          cv = 3, n_jobs = -1, verbose = 2)

grid_search.fit(X_train_counts, y_train)

y_predicted_counts = grid_search.predict(X_test_counts)

accuracy, precision, recall, f1 = get_metrics(y_test, y_predicted_counts)
# Out:
# Fitting 3 folds for each of 180 candidates, totalling 540 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done 333 tasks      | elapsed:   21.9s
# [Parallel(n_jobs=-1)]: Done 540 out of 540 | elapsed:   37.8s finished

# %%
grid_search.best_params_
# Out:
# {'bootstrap': False,
#  'max_depth': None,
#  'max_features': 'auto',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 65}

# %%
grid_search.best_score_
# Out:
# 0.9261709330267319

# %%
print("accuracy = %.3f, precision = %.3f, recall = %.3f, f1 = %.3f" % (accuracy, precision, recall, f1))
# Out:
# accuracy = 0.897, precision = 0.892, recall = 0.897, f1 = 0.881

# %%
confusion_matrix(y_test, y_predicted_counts)
# Out:
# array([[ 51,  81],
#        [ 10, 745]], dtype=int64)

# %%
nb = MultinomialNB()

# %%
nb.fit(X_train_counts, y_train)

y_predicted_counts = nb.predict(X_test_counts)

accuracy, precision, recall, f1 = get_metrics(y_test, y_predicted_counts)
print("accuracy = %.3f, precision = %.3f, recall = %.3f, f1 = %.3f" % (accuracy, precision, recall, f1))
# Out:
# accuracy = 0.885, precision = 0.874, recall = 0.885, f1 = 0.865

# %%
confusion_matrix(y_test, y_predicted_counts)
# Out:
# array([[ 44,  88],
#        [ 14, 741]], dtype=int64)

# %%
# 1. tf-idf
# 2. SMOTE
# 3. Lemmatize
# 4. Bigrams + Trigrams
